# %% [markdown]
# # Web Scraping the Dros 2019 Abstract data
# The data for abstracts at this conference comes in two parts - first, the PDF that actually has all the abstracts in them. However, that PDF doesn't have the abstract assignment (poster or talk). For the assignment, we need the conference web page: http://conferences.genetics-gsa.org/drosophila/2019/assignments
#
# The assignments are in a large table, that is thankfully continuous over the whole page. The table has the presenter's name, partial abstract title, session assignment, program #, session date, and presentation time. We need hte session assignment and the program number. The number will allow us to connect it to the correct abstract in the program.
#
# I've saved the web page in this folder in case it changes or gets removed. At this point it's not going to change anyway.

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
# we tell BeautifulSoup and tell it which parser to use
soup = BeautifulSoup(open("dros_2019_data/abstract_lookup.html"), "html.parser")
# the output corresponds exactly to the html file
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <!-- BC_OBNW -->
# <head>
# <title>ABSTRACTS: Assignments Lookup</title>
# <link href="/StyleSheets/ModuleStyleSheets.css" rel="StyleSheet" type="text/css"/>
# <script type="text/javascript">var jslang='EN';</script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport">
# <title>ABSTRACTS: Assignments Lookup</title>
# <link href="/favicon.png" rel="shortcut icon"/>
# <link href="/home_badge_64.png" rel="apple-touch-icon"/>
# <link href="/home_badge_64.png" rel="apple-touch-icon-precomposed"/>
# <link href="/_System/apps/thr-bootstrap/public/stylesheets.min.css" rel="stylesheet"/>
# <!--<link rel="stylesheet" href="/_assets/css/bootstrap.min.css">-->
# <link href="/_assets/css/jasny-bootstrap.min.css" rel="stylesheet"/>
# <link href="/_assets/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Poppins:300,400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:100,100i,300,300i,400,400i,700,700i,900,900i" rel="stylesheet"/>
# <link href="/_assets/css/slick.css" rel="stylesheet">
# <link href="/_assets/css/elegant-font.css" rel="stylesheet">
# <link href="/_assets/css/ionicons.min.css" rel="stylesheet">
# <link href="/_assets/css/magnific.min.css" rel="stylesheet">
# <link href="/stylesheets/screen.css" rel="stylesheet">
# <link href="/stylesheets/bannercolors.css" rel="stylesheet"/>
# <link href="/css/custom.css" rel="stylesheet"/>
# <script src="/_assets/js/jquery.min.js"></script>
# <!--[if lt IE 9]>
# <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.6.2/html5shiv.js"></script>
# <script src="//s3.amazonaws.com/nwapi/nwmatcher/nwmatcher-1.2.5-min.js"></script>
# <script src="//html5base.googlecode.com/svn-history/r38/trunk/js/selectivizr-1.0.3b.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.1.0/respond.min.js"></script>
# <![endif]-->
# <style>
# .idYear {font-size: 18px; font-weight: bold;}
# .idDay {18px; font-weight: bold;}
# </style>
# <style type="text/css">
#     body {
#         font-size: 14px;
#     }
#     table {
#         font-size: 14px;
#     }
#     tr,
#     td {
#         padding: 5px;
#     }
#     .lname {
#         color: #212529;
#         font-weight: 500;
#     }
#     .individual-name {
#         color: #007bff;
#         font-weight: 400;
#         cursor: pointer;
#     }
# </style>
# <style type="text/css">
# [id^=authassign] th, td{
#     border: 1px solid #000;
# }
# </style>
# </link></link></link></link></link></meta></head>
# <body id="drosophila">
# <!---===--==//	HEADER	\\==--===--->
# <section id="search-container-1">
# <div class="container">
# <form action="/Default.aspx?SiteSearchID=-1&amp;PageID=16287759" method="post" name="catsearchform24099">
# <div class="col-xs-9">
# <input class="" id="CAT_Search" name="CAT_Search" placeholder="Search" type="text"/> </div>
# <div class="col-xs-3">
# <input class="" type="submit" value="Search"/> </div>
# </form>
# </div>
# </section>
# <header id="header-1">
# <!-- Header-Menu -->
# <div class="contain-to-grid">
# <div class="container">
# <div class="top-bar">
# <div class="row logo-big resp-lg hidden-md-down">
# <div class="col-sm-4 px-0">
# <a href="http://www.genetics-gsa.org" target="_blank"><img alt="GSA logo" class="img-fluid" height="74" src="/_assets/image/gsa-logo.png" width="140"/>
# </a>
# </div>
# <div class="col-sm-8 px-0">
# <a href="http://conferences.genetics-gsa.org"><img alt="GSA Conference logo" class="img-fluid" height="74" src="/_assets/image/conf-logo.png" width="280"/>
# </a>
# </div>
# </div>
# <div class="row logo-big resp-md hidden-sm-down hidden-lg-up">
# <div class="col-sm-4 px-0">
# <a href="http://www.genetics-gsa.org" target="_blank"><img alt="GSA logo" class="img-fluid" src="/_assets/image/gsa-logo.png"/>
# </a>
# </div>
# <div class="col-sm-8 px-0">
# <a href="http://conferences.genetics-gsa.org"><img alt="GSA Conference logo" class="img-fluid" src="/_assets/image/conf-logo.png"/>
# </a>
# </div>
# </div>
# <div class="row logo-big resp-sm hidden-md-up">
# <div class="col-xs-4 px-0">
# <a href="http://www.genetics-gsa.org" target="_blank"><img alt="GSA logo" class="img-fluid" height="44" src="/_assets/image/gsa-logo-xs@2x.png" title="GSA logo" width="78"/>
# </a>
# </div>
# <div class="col-xs-8 px-0">
# <a href="http://conferences.genetics-gsa.org"><img alt="GSA Conference logo" class="img-fluid" height="44" src="/_assets/image/conf-logo-xs@2x.png" title="GSA Conference logo" width="162"/>
# </a>
# </div>
# </div>
# <div class="top-bar-title">
# <div class="search">
# <a class="fa fa-search" href="#"> </a>
# </div>
# </div>
# <div id="responsive-menu">
# <div class="menu-container">
# <div class="menu hidden-sm-down">
# <ul>
# <li class="one-column-dropdown">
# <a href="/">Home</a> </li>
# <li class="one-column-dropdown">
# <a href="">Conferences</a> <ul>
# <li>
# <a href="/Celegans/2019/index"><em>C. <span style="text-transform:lowercase">e</span>legans</em>
# </a> </li>
# <li>
# <a href="/chlamydomonas/index">Chlamydomonas
#
#             </a> </li>
# <li>
# <a href="/Ciliate/2018/index">Ciliate
#
#             </a> </li>
# <li>
# <a href="/drosophila/2019/index">Drosophila
#
#             </a> </li>
# <li>
# <a href="/Fungal/2019/index">Fungal
#
#             </a> </li>
# <li>
# <a href="/mouse/index">Mouse
#
#             </a> </li>
# <li>
# <a href="/peqg/2018/index">Pop / Evo / Quant
#
#             </a> </li>
# <li>
# <a href="/xenopus/2018/index">Xenopus
#
#             </a> </li>
# <li>
# <a href="/yeast/2018/index">Yeast
#
#             </a> </li>
# <li>
# <a href="/zebrafish/index">Zebrafish
#
#             </a> </li>
# <li>
# <a href="/tagc/2020/index">The Allied Genetics Conference
#
#             </a> </li>
# </ul>
# </li>
# <li>
# <a href="/contact-us">Contact</a> </li>
# <li class="one-column-dropdown">
# <a href="">About GSA</a> <ul>
# <li>
# <a href="http://www.genetics-gsa.org/about/" target="_blank">About GSA
#
#             </a> </li>
# <li>
# <a href="http://www.genetics-gsa.org/" target="_blank">GSA Website
#
#             </a> </li>
# <li>
# <a href="http://www.genetics-gsa.org/membership/" target="_blank">Join GSA
#
#             </a> </li>
# </ul>
# </li>
# <li class="search">
# <a class="fa fa-search" href="#"></a>
# </li> </ul>
# </div>
# <div class="menu hidden-md-up">
# <ul>
# <li>
# <a href="/drosophila/2017/index">Drosophila Home</a> </li>
# <li>
# <a href="/Drosophila/2017/abstracts">Abstracts</a> <ul>
# <li>
# <a href="/drosophila/2017/submission-rules">Submission Rules
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/submission">Submission
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/revisions-and-withdrawals">Revisions and Withdrawals
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/author-assignments">Author Assignments
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/presentation-guidelines">Presentation Guidelines
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/conference-materials">Full text of Abstracts
#
#             </a> </li>
# </ul>
# </li>
# <li>
# <a href="/drosophila/2017/registration">Registration</a> <ul>
# <li>
# <a href="/drosophila/2017/fees">Fees
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/register-now">Register Now
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/register-onsite">Register On-Site
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/confirmation">Confirmation
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/cancellations">Cancellations
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/list-of-registrants">List of Registrants
#
#             </a> </li>
# </ul>
# </li>
# <li>
# <a href="/program">Program</a> <ul>
# <li>
# <a href="/drosophila/2017/agenda">Agenda
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/invited-speakers">Invited Speakers
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/special-events">Special Events
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/conference-and-travel-awards">Conference and Travel Awards
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/conference-materials">Conference Materials
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/meeting-app">Meeting App
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/abstract-search-and-program-planner">Abstract Search &amp; Program Planner
#
#             </a> </li>
# </ul>
# </li>
# <li>
# <a href="/exhibits">Exhibits &amp; Sponsorship</a> <ul>
# <li>
# <a href="/drosophila/2017/exhibits">Exhibits
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/sponsorship">Sponsorship
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/advertising">Advertising
#
#             </a> </li>
# </ul>
# </li>
# <li>
# <a href="/Travel">Travel</a> <ul>
# <li>
# <a href="/drosophila/2017/housing">Housing
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/ground-transportation">Ground Transportation
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/international-attendees">International Attendees
#
#             </a> </li>
# <li>
# <a href="/drosophila/2017/room-sharing">Room Sharing
#
#             </a> </li>
# </ul>
# </li>
# <li>
# <a href="/drosophila/2017/general-information">General Information</a> </li>
# <li>
# <a href="/drosophila/2017/past-and-upcoming-conferences">Past &amp; Upcoming Conferences</a> </li>
# <li class="search">
# <a class="fa fa-search" href="#"></a>
# </li> </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <!---===--==//	Banner	\\==--===--->
# <section id="comm-page-banner-1">
# <div class="dros-bg banner-line"></div>
# </section>
# <!---===--==//	Pagecontent	\\==--===--->
# <section class="home-1-top-bottom-25" id="one-column">
# <div class="container">
# <div class="row">
# <div class="col-sm-12 col-marg-top-20">
# <div class="bcrumb">
# <small><a href="/drosophila/2019/index">Drosophila Home</a>   <em aria-hidden="true" class="fa fa-angle-double-right"></em>   ABSTRACTS: Assignments Lookup</small>
# </div>
# <div class="two-column-content">
# <p>Please click on the first letter of the presenting author's last name to view the assignment for either an oral or poster presentation. It is not possible to view abstract assignments
#     using co-author names.  Poster Preview presentations are new this year and each person given a two-minute Poster Preview assignment will also
#     have a poster presentation.</p>
# <p>Student and postdoc GSA members: amplify your work and seek expert feedback by inviting specific scientists to attend your poster presentation via <a href="https://www.surveymonkey.com/r/H35PHXW">this request form</a>.</p>
# <p>If you have any questions or comments, please contact <a href="mailto:sbrown@genetics-gsa.org">sbrown@genetics-gsa.org</a>.</p>
# <!--div class="input-group" style="margin: 5px 0 20px 0"><input type="text" class="form-control" name="srchstring" placeholder="enter institution, country, or name">&nbsp;<button type="button" class="btn btn-info" id='search-btn'>Search</button></div-->
# <ul class="nav nav-pills">
# <li class="nav-item"> <a class="nav-link active" data-toggle="tab" href="#lname-All" role="tab">All</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-A" role="tab">A</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-B" role="tab">B</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-C" role="tab">C</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-D" role="tab">D</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-E" role="tab">E</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-F" role="tab">F</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-G" role="tab">G</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-H" role="tab">H</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-I" role="tab">I</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-J" role="tab">J</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-K" role="tab">K</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-L" role="tab">L</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-M" role="tab">M</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-N" role="tab">N</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-O" role="tab">O</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-P" role="tab">P</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-Q" role="tab">Q</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-R" role="tab">R</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-S" role="tab">S</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-T" role="tab">T</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-U" role="tab">U</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-V" role="tab">V</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-W" role="tab">W</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-X" role="tab">X</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-Y" role="tab">Y</a> </li>
# <li class="nav-item"> <a class="nav-link" data-toggle="tab" href="#lname-Z" role="tab">Z</a> </li>
# </ul>
# <div class="tab-content" id="myTabContent">
# <div class="tab-pane active" id="lname-All" role="tabpanel">
# <p>Total matched author(s): <span id="lname-All-count">926</span></p>
# <br/>
# <table align="center" border="1" cellpadding="2" class="table-responsive table-hover table-striped" id="authassign-All" style="border-collapse: collapse;border: 1px solid #000">
# <tr>
# <th style="padding-right: 10px">Presenter's Name</th>
# <th>Partial<br/>Abstract Title</th>
# <th>Session Assignment</th>
# <th>Program #</th>
# <th>Session Dates<!--br>&&nbsp;Locations--></th>
# <th>Presentation Time</th>
# </tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Abdal-Rhida, Muna<!--/span--></td>
# <td valign="top">Transcriptional regulation of <em>robo2 </em>in the ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Neural development and physiology</td>
# <td valign="top">643</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Abdalla, Jasmina<!--/span--></td>
# <td valign="top">Epigenetic Inheritance of Alcohol ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Physiology, metabolism and aging</td>
# <td valign="top">634</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Abdalla, Jasmina<!--/span--></td>
# <td valign="top">Epigenetic Inheritance of Alcohol ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Poster Preview</a><br/>Physiology, Metabolism and Aging II</td>
# <td valign="top">634P</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 6:21 PM-6:23 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Abdulazeez, Rashidatu<!--/span--></td>
# <td valign="top">Introducing the fruit fly as a powerful ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Educational Initiatives</td>
# <td valign="top">825</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Abrams, John M.<!--/span--></td>
# <td valign="top">p53 genes and the game of transposons.</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Plenary</a><br/>Plenary II</td>
# <td valign="top">155</td>
# <td valign="top">
# Sunday, March 31</td>
# <td valign="top">
# 8:30 AM-9:00 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Adhikari, Kiran<!--/span--></td>
# <td valign="top">Genotype-by-temperature interactions ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Evolution II</td>
# <td valign="top">129</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 4:45 PM-5:00 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Aerts, Stein<!--/span--></td>
# <td valign="top">Techniques and computational methods for ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Plenary</a><br/>Techniques &amp; Technology</td>
# <td valign="top">152</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 8:45 PM-9:00 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Agapite, Julie<!--/span--></td>
# <td valign="top">FlyBase: a valuable source of molecular ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Techniques &amp; Technology</td>
# <td valign="top">815</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Ahmad, Kami<!--/span--></td>
# <td valign="top">Chromatin reprogramming by the histone ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Chromatin, Epigenetics and Genomics II</td>
# <td valign="top">101</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 9:45 AM-10:00 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Ahmad, Vakil<!--/span--></td>
# <td valign="top"><em>Syd</em>/<em>Mapk8ip3</em> regulates Hippo signaling to ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell division and cell growth</td>
# <td valign="top">837</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Akeju, Miriam<!--/span--></td>
# <td valign="top">Meiotic sex chromosome inactivation in the ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Chromatin, epigenetics and genomics</td>
# <td valign="top">430</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Akeju, Miriam<!--/span--></td>
# <td valign="top">Meiotic sex chromosome inactivation in the ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Poster Preview</a><br/>Chromatin, Epigenetics and Genomics II</td>
# <td valign="top">430P</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 10:06 AM-10:08 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Akin, Orkun<!--/span--></td>
# <td valign="top">Cell-type specific patterned ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Neural Development and Physiology</td>
# <td valign="top">39</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 8:30 AM-8:45 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Al hayek , Sandy<!--/span--></td>
# <td valign="top">Shavenbaby isoforms orchestrate the ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Stem Cells, Regeneration and Tissue Injury</td>
# <td valign="top">122</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 11:15 AM-11:30 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Aldrich, John C.<!--/span--></td>
# <td valign="top">The palmitoyltransferase, <em>Patsas</em> is a ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">735</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Alhadyian, Haifa<!--/span--></td>
# <td valign="top"><em>Macroglobulin complement-related</em> is ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Patterning, morphogenesis and organogenesis</td>
# <td valign="top">469</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->AlHaj Abed, Jumana S.<!--/span--></td>
# <td valign="top">The global, multilayer structure of ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Regulation of Gene Expression II/ Chromatin, Epigenetics and Genomics I</td>
# <td valign="top">68</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 12:00 PM-12:15 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Ali, Sammi<!--/span--></td>
# <td valign="top">Quantitative spatial gene expression in ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Patterning, morphogenesis and organogenesis</td>
# <td valign="top">451</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Alizzi, Rebecca<!--/span--></td>
# <td valign="top">Found in neurons (Fne) promotes an ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Neural development and physiology</td>
# <td valign="top">655</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Alkema, Jeroen<!--/span--></td>
# <td valign="top">Fighting flies with context.</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Reproduction and gametogenesis</td>
# <td valign="top">343</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Almazan-Herrera, Steven  J.<!--/span--></td>
# <td valign="top">Analysis of the<em>mps-1 </em>T Mps1-PP1 interaction ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell division and cell growth</td>
# <td valign="top">568</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Alonso, Valentina<!--/span--></td>
# <td valign="top">The nematode-associated bacterium <em></em> ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Immunity and the microbiome</td>
# <td valign="top">193</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Amini, Mina<!--/span--></td>
# <td valign="top">Dystrophin's roles, subcellular ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell biology: cytoskeleton, organelles and trafficking</td>
# <td valign="top">513</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Amodeo, Amanda A.<!--/span--></td>
# <td valign="top">Dynamics of free and chromatin-bound ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Chromatin, epigenetics and genomics</td>
# <td valign="top">408</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Amodeo, Amanda A.<!--/span--></td>
# <td valign="top">Dynamics of free and chromatin-bound ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Poster Preview</a><br/>Regulation of Gene Expression II/ Chromatin, Epigenetics and Genomics I</td>
# <td valign="top">408P</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 12:21 PM-12:23 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Andrade, Ingrid V.<!--/span--></td>
# <td valign="top">Developmentally arrested precursors of ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Neural circuits and behavior</td>
# <td valign="top">715</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Andrews, Jonathan C.<!--/span--></td>
# <td valign="top">A rescue based screen to functionally ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">756</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Angstmann, Hanna<!--/span--></td>
# <td valign="top">Serpin <em>scca1</em> dysregulation in <em>Drosophila</em> ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">784</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Anreiter, Ina<!--/span--></td>
# <td valign="top">Promoter-specific histone methylation and ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Regulation of Gene Expression I</td>
# <td valign="top">46</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 8:45 AM-9:00 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Antwi-Adjei, Emmanuel<!--/span--></td>
# <td valign="top">The neuronal design underlying ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Neural circuits and behavior</td>
# <td valign="top">688</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Antwi-Adjei, Emmanuel<!--/span--></td>
# <td valign="top">The neuronal design underlying ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Poster Preview</a><br/>Neural Development and Physiology II/Neural Circuits and Behavior II</td>
# <td valign="top">688P</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 6:19 PM-6:21 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Aponte, Camila<!--/span--></td>
# <td valign="top">Identifying new synaptonemal complex ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Reproduction and gametogenesis</td>
# <td valign="top">333</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Arkov, Alexey L.<!--/span--></td>
# <td valign="top">Structure-function analysis of germ ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Reproduction and gametogenesis</td>
# <td valign="top">345</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Arnosti, David N.<!--/span--></td>
# <td valign="top">Diversification of retinoblastoma protein ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Regulation of gene expression</td>
# <td valign="top">364</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Asahina, Kenta<!--/span--></td>
# <td valign="top">The <em>nervy</em> gene modulates aggression levels ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Neural Circuits and Behavior I</td>
# <td valign="top">56</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 12:00 PM-12:15 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Assis, Raquel<!--/span--></td>
# <td valign="top">Out of the testis, into the ovary: biased ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Chromatin, epigenetics and genomics</td>
# <td valign="top">432</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Attrill, Helen Louise<!--/span--></td>
# <td valign="top">An evidence-based model for representing ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Signal transduction</td>
# <td valign="top">503</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Avalos, Matthew<!--/span--></td>
# <td valign="top">Screens in Drosophila and cell line models ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">788</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Avelino, Camila C.<!--/span--></td>
# <td valign="top">Spermatogenic stage-specific expression in ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Reproduction and gametogenesis</td>
# <td valign="top">328</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Baker, Brandon<!--/span--></td>
# <td valign="top">Dissecting the Genetic Basis of Variation ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">794</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Balasov, Maxim L.<!--/span--></td>
# <td valign="top">The structural and functional analysis of ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">769</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Baldwin-Brown, James Guy<!--/span--></td>
# <td valign="top">Major parts of <em>Drosophila</em> hybrid genomes ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Chromatin, epigenetics and genomics</td>
# <td valign="top">425</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Bandura, Jennifer<!--/span--></td>
# <td valign="top">The deubiquitinase <em>Usp5</em> is required for ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell division and cell growth</td>
# <td valign="top">565</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Banerjee, Swati<!--/span--></td>
# <td valign="top">Tubulin polymerization promoting protein, ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell biology: cytoskeleton, organelles and trafficking</td>
# <td valign="top">549</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Banerjee, Swati<!--/span--></td>
# <td valign="top">Tubulin polymerization promoting protein, ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Poster Preview</a><br/>Cell Biology: Cytoskeleton, Organelles, Trafficking</td>
# <td valign="top">549P</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 10:06 AM-10:08 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Bangerter, Alyssa S.<!--/span--></td>
# <td valign="top">Fine-scale temporal sampling shows ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Evolution</td>
# <td valign="top">263</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Bangi, Erdem<!--/span--></td>
# <td valign="top">A personalized approach to treat a KRAS ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Models of Human Disease II</td>
# <td valign="top">69</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 4:30 PM-4:45 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Bao, Mengjing<!--/span--></td>
# <td valign="top">Function of tyrosination of ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell biology: cytoskeleton, organelles and trafficking</td>
# <td valign="top">510</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Barnes, Phillip T.<!--/span--></td>
# <td valign="top">Partial behavioral isolation between a ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Evolution</td>
# <td valign="top">240</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Barretto, Elizabeth<!--/span--></td>
# <td valign="top">FOXO is a hypoxia-inducible transcription ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Physiology, Metabolism and Aging I</td>
# <td valign="top">57</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 10:45 AM-11:00 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Barron, Alexander J.<!--/span--></td>
# <td valign="top">Establishment and persistence of ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Immunity and the microbiome</td>
# <td valign="top">206</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Bauer, Johannes H.<!--/span--></td>
# <td valign="top">Altered pheromone biosynthesis is ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Physiology, metabolism and aging</td>
# <td valign="top">611</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Bauerly, Elisabeth<!--/span--></td>
# <td valign="top">Arms are required for swimming: The role ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Reproduction and gametogenesis</td>
# <td valign="top">313</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->BAWA, SIMRANJOT<!--/span--></td>
# <td valign="top">Altered metabolism in Trim32 deficient ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">771</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Baxter, Chris<!--/span--></td>
# ...
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhang, Wei<!--/span--></td>
# <td valign="top">Comparative transcriptomics provides ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Evolution</td>
# <td valign="top">264</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhang, Xuedi<!--/span--></td>
# <td valign="top">Probing the function of metazoan histones ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Chromatin, epigenetics and genomics</td>
# <td valign="top">409</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhang, Yngbiao<!--/span--></td>
# <td valign="top">The GATOR2 complex regulates the dynamic ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell stress and cell death</td>
# <td valign="top">170</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhang, Yu<!--/span--></td>
# <td valign="top">Regulation of Axon Targeting in the <em></em> ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Neural development and physiology</td>
# <td valign="top">645</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhao, Heya<!--/span--></td>
# <td valign="top">Regulation of epidermal cell ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Signal Transduction</td>
# <td valign="top">104</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 9:00 AM-9:15 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhao, Li<!--/span--></td>
# <td valign="top">An evolutionary perspective on gene ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Chromatin, epigenetics and genomics</td>
# <td valign="top">431</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhao, Li<!--/span--></td>
# <td valign="top">An evolutionary perspective on gene ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Poster Preview</a><br/>Chromatin, Epigenetics and Genomics II</td>
# <td valign="top">431P</td>
# <td valign="top">
# Saturday, March 30</td>
# <td valign="top">
# 10:04 AM-10:06 AM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhao, Yunpo<!--/span--></td>
# <td valign="top">Stop codon readthrough of a POU/Oct ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Regulation of gene expression</td>
# <td valign="top">358</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zheng, Huimei<!--/span--></td>
# <td valign="top">Pif1A, the Drosophila homolog of human ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Reproduction and gametogenesis</td>
# <td valign="top">306</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zheng, Xiaoyue<!--/span--></td>
# <td valign="top">Proteomic analysis and genetic modifier ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">728</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhou, Jun<!--/span--></td>
# <td valign="top">A tumor-microbe self-enforcing loop ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Models of Human Disease II</td>
# <td valign="top">71</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 5:00 PM-5:15 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhou, Lingjian<!--/span--></td>
# <td valign="top">Screening for secretion genes in fat body ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Cell biology: cytoskeleton, organelles and trafficking</td>
# <td valign="top">534</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhou, Rui<!--/span--></td>
# <td valign="top">Role of Circular RNAs<em> </em>in Innate Immunity ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Platform</a><br/>Immunity and the Microbiome</td>
# <td valign="top">10</td>
# <td valign="top">
# Thursday, March 28</td>
# <td valign="top">
# 5:00 PM-5:15 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhu, Hailun<!--/span--></td>
# <td valign="top">Regulation of Ey Expression in <em>Drosophila</em> ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Neural development and physiology</td>
# <td valign="top">673</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhu, Michael<!--/span--></td>
# <td valign="top">The microbiome's effect on the ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#oralPresentations" target="_">Poster Preview</a><br/>Models of Human Disease II</td>
# <td valign="top">739P</td>
# <td valign="top">
# Friday, March 29</td>
# <td valign="top">
# 6:15 PM-6:17 PM</td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhu, Michael<!--/span--></td>
# <td valign="top">The microbiome's effect on the ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Models of human disease</td>
# <td valign="top">739</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zhuang, Xuan<!--/span--></td>
# <td valign="top">Genetic basis of variation in high sugar ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Evolution</td>
# <td valign="top">250</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>2:00 - 3:00 PM<br/>Friday, March 29<br/>9:00 - 10:00 PM<br/>Saturday, March 30<br/>1:30 - 2:30 PM
# </td></tr>
# <tr class="listing">
# <td style="margin-left:10px" valign="top"><!--span class="individual-name"-->Zirin, Jonathan D.<!--/span--></td>
# <td valign="top">Large scale sgRNA libraries for in vivo ...</td>
# <td valign="top">
# <a href="http://conferences.genetics-gsa.org/drosophila/2019/presentation-guidelines#posterPresentations" target="_">Poster</a><br/>Techniques &amp; Technology</td>
# <td valign="top">809</td>
# <td valign="top">
#             Thursday - Saturday<br/>March 28 - 30
# </td>
# <td valign="top">
#             Thursday, March 28<br/>3:00 - 4:00 PM<br/>Friday, March 29<br/>8:00 - 9:00 PM<br/>Saturday, March 30<br/>2:30 - 3:30 PM
# </td></tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section id="purchasenow-1">
# <div class="container">
# <div class="purchasenow-1 text-xs-center">
# <p>BECOME A MEMBER AND GET A DISCOUNT! JOIN TODAY</p>
# <a class="button" href="http://www.genetics-gsa.org/membership/" target="_blank">BECOME A GSA MEMBER</a>
# </div>
# </div>
# </section>
# <!---===--==//	Footer	\\==--===--->
# <footer id="footer-1">
# <div class="footer-top-1">
# <div class="container">
# <div class="footer-1-menu">
# <div class="row">
# <div class="col-md-6 col-xs-12 pull-left-new">
# <div class="col-md-6 col-sm-6">
# <div class="footer-1-sub1"> <a href="http://www.genetics-gsa.org" target="_blank">
# <img alt="gsa logo" src="/_assets/image/gsa-logo-footer.png"/>
# </a>
# <p>The Genetics Society of America (GSA) is an international professional membership organization for scientific researchers and educators in the field of genetics. We are dedicated to promoting genetics research and to facilitating communication among geneticists worldwide.</p>
# </div>
# </div>
# <div class="col-md-6 col-sm-6">
# <div class="footer-1-sub2">
# <div class="footer-1-title">
# <h2>Useful Links</h2>
# </div>
# <div class="footer-1-content-1">
# <ul>
# <li><a href="http://genetics-gsa.org"><em class="fa fa-angle-right"></em>GSA</a></li><li><a href="/contact-us"><em class="fa fa-angle-right"></em>Contact Us</a></li><li><a href="/contact-us"><em class="fa fa-angle-right"></em>Site Support</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-6 col-xs-12 pull-right-new">
# <div class="col-md-6 col-sm-6">
# <div class="footer-1-sub3">
# <div class="footer-1-title">
# <h2>Stay Up to date</h2>
# </div>
# <div class="footer-1-content-2">
# <p class="fText">Signup for email news, discounts<br/>
# and more</p>
# <a class="btn btn-primary" href="/newsletter-signup">Newsletter Signup</a>
# </div>
# </div>
# </div>
# <div class="col-md-6 col-sm-6">
# <div class="footer-1-sub4">
# <div class="footer-1-title">
# <h2>Get In Touch</h2>
# </div>
# <div class="footer-1-content-3">
# <ul class="footer-adress">
# <li><em aria-hidden="true" class="fa fa-map-marker"></em>
# <p>6120 Executive Boulevard, Suite 550, Rockville, MD 20852</p>
# </li>
# <li><em aria-hidden="true" class="fa fa-phone"></em>
# <p><a href="tel:240-880-2000">(240) 880-2000</a></p>
# </li>
# <li><em aria-hidden="true" class="fa fa-envelope-o"></em>
# <p><a href="mailto:gsaconferences@genetics-gsa.org">GSAConferences@genetics-gsa.org</a></p>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-bottom-1">
# <div class="container">
# <div class="footer-bottom1-copyright">
# <p>Copyright © 2019 Genetics Society of America</p>
# </div>
# <div class="footer-bottom1-socialicon">
# <p>Social network:</p>
# <ul>
# <li>
# <a class="fa fa-facebook" href="https://www.facebook.com/GeneticsGSA"></a>
# </li><li>
# <a class="fa fa-twitter" href="http://twitter.com/GeneticsGSA"></a>
# </li><li>
# <a class="fa fa-google" href="https://plus.google.com/106737238985338171845"></a>
# </li><li>
# <a class="fa fa-linkedin" href="http://www.linkedin.com/groups/Genetics-Society-America-GSA-4533930"></a>
# </li><li>
# <a class="fa fa-youtube" href="http://www.youtube.com/user/GeneticsSociety"></a>
# </li><li>
# <a class="fa fa-instagram" href="https://www.instagram.com/geneticsgsa/"></a>
# </li>
# </ul>
# </div>
# <div class="bottom-top-scroll-1"> <a class="fa fa-angle-up" href="#" id="backtotop-1"></a> </div>
# </div>
# </div>
# </footer>
# <!---===--==//	Scripts	 \\==--===--->
# <script src="/_assets/js/tether.min.js"></script>
# <script src="/_System/apps/thr-bootstrap/public/scripts.min.js"></script>
# <!--<script src="/_assets/js/bootstrap.min.js"></script>-->
# <script src="/_assets/js/jasny-bootstrap.min.js"></script>
# <script src="/_assets/js/slick.min.js"></script>
# <script src="/_assets/js/megamenu.js"></script>
# <script src="/_assets/js/magnific.min.js"></script>
# <script src="/_assets/js/matchheight.min.js"></script>
# <script src="/_assets/js/jquery.mixitup.min.js"></script>
# <script src="/_assets/js/holder.min.js"></script>
# <script src="/_assets/js/custom.js"></script>
# <script src="/_assets/js/retina.js"></script>
# <script>
# $(function(){
#   $('.subnav a').filter(function(){return this.pathname==window.location.pathname}).closest('ul').show();
#   $('.subnav a').filter(function(){return this.pathname==window.location.pathname}).addClass('side-active');
# });
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-2214516-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <!--- start: simplefeedback.com --->
# <script type="text/javascript">
# var sfb_params = { "host": (("https:" == document.location.protocol) ? "https://" : "http://"), "site": "2D3FBCFFE8A44D7F02A2B8C374085B84F0284201", "id": "6248" };
# (function(d, t) { var g = d.createElement(t), s = d.getElementsByTagName(t)[0]; g.src = sfb_params.host+'dalit6msb4eer.cloudfront.net/scripts/forms/sfb_init.js'; s.parentNode.insertBefore(g, s); }(document, 'script'));
# </script>
# <!--- end: simplefeedback.com --->
# </body>
# </html>

# %%
ab_table = soup.find(id="authassign-All")
abstracts = pd.read_html(str(ab_table))[0]
abstracts.head()
# Out:
#         Presenter's Name                           PartialAbstract Title  \
# 0      Abdal-Rhida, Muna  Transcriptional regulation of robo2 in the ...
# 1       Abdalla, Jasmina           Epigenetic Inheritance of Alcohol ...
# 2       Abdalla, Jasmina           Epigenetic Inheritance of Alcohol ...
# 3  Abdulazeez, Rashidatu     Introducing the fruit fly as a powerful ...
# 4        Abrams, John M.          p53 genes and the game of transposons.
#
#                                   Session Assignment Program #  \
# 0            PosterNeural development and physiology       643
# 1             PosterPhysiology, metabolism and aging       634
# 2  Poster PreviewPhysiology, Metabolism and Aging II      634P
# 3                      PosterEducational Initiatives       825
# 4                                  PlenaryPlenary II       155
#
#                       Session Dates  \
# 0  Thursday - SaturdayMarch 28 - 30
# 1  Thursday - SaturdayMarch 28 - 30
# 2                  Friday, March 29
# 3  Thursday - SaturdayMarch 28 - 30
# 4                  Sunday, March 31
#
#                                    Presentation Time
# 0  Thursday, March 283:00 - 4:00 PMFriday, March ...
# 1  Thursday, March 282:00 - 3:00 PMFriday, March ...
# 2                                    6:21 PM-6:23 PM
# 3  Thursday, March 283:00 - 4:00 PMFriday, March ...
# 4                                    8:30 AM-9:00 AM

# %%
assignments = {}

for idx, num in enumerate(abstracts['Program #'].values):
    if "P" not in num:
  
        if "Poster" in abstracts['Session Assignment'].values[idx]:
            assignments[num] = {
                'type' : 'poster',
                'section' : abstracts['Session Assignment'].values[idx].split('Poster')[1].lower()
            }

        if "Plenary" in abstracts['Session Assignment'].values[idx]:
            assignments[num] = {
                'type' : 'talk',
                'section' : abstracts['Session Assignment'].values[idx][7:].lower()
            }

        if "Platform" in abstracts['Session Assignment'].values[idx]:
            assignments[num] = {
                'type' : 'talk',
                'section' : abstracts['Session Assignment'].values[idx].split('Platform')[1].lower()
            }

sections = set()
for assign in assignments:
    sections.add(assignments[assign]['section'])

# %% [markdown]
# There are many secitons, and several fall into the same general category of study. So, I've made these group categories to narrow down the general thing that is being studied. Later we can try plotting by sections and by groups

# %%
section_groups = {
    'cell biology: cytoskeleton, organelles and trafficking' : 'cell bio',
    'cell biology: cytoskeleton, organelles, trafficking' : 'cell bio',
    'cell death and cell stress' : 'cell bio',
    'cell division and cell growth' : 'cell bio',
    'cell division and growth control' : 'cell bio',
    'cell stress and cell death' : 'cell bio',
    'chromatin, epigenetics and genomics' : 'gene expression',
    'chromatin, epigenetics and genomics ii' : 'gene expression',
    'education ' : 'education',
    'educational initiatives' : 'education',
    'evolution' : 'evolution',
    'evolution i' : 'evolution',
    'evolution ii' : 'evolution',
    'immunity and the microbiome' : 'models of human disease',
    'models of human disease' : 'models of human disease',
    'models of human disease i' : 'models of human disease',
    'models of human disease ii' : 'models of human disease',
    'neural circuits and behavior' : 'neurobiology',
    'neural circuits and behavior i' : 'neurobiology',
    'neural development and physiology' : 'neurobiology',
    'neural development and physiology ii/neural circuits and behavior ii'  : 'neurobiology',
    'patterning, morphogenesis and organogenesis' : 'developmental biology',
    'patterning, morphogenesis and organogenesis i' : 'developmental biology',
    'patterning, morphogenesis and organogenesis ii' : 'developmental biology',
    'physiology, metabolism and aging' : 'developmental biology',
    'physiology, metabolism and aging i' : 'developmental biology',
    'physiology, metabolism and aging ii' : 'developmental biology',
    'plenary ii' : 'plenary',
    'plenary session i' : 'plenary',
    'regulation of gene expression' : 'gene expression',
    'regulation of gene expression i' : 'gene expression',
    'regulation of gene expression ii/ chromatin, epigenetics and genomics i' : 'gene expression',
    'reproduction and gametogenesis'  : 'developmental biology',
    'signal transduction'  : 'developmental biology',
    'stem cells, regeneration and tissue injury'  : 'developmental biology',
    'techniques & technology' : 'education'    
}

# %%
groups = set()
for assign in assignments:
    assignments[assign]['group'] = section_groups[assignments[assign]['section']]
    groups.add(assignments[assign]['group'])
    
print(len(assignments), 'assignments')
# Out:
# 844 assignments
